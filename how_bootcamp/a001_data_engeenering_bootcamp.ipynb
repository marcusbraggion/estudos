# %%
import requests
import pandas as pd

# %%
url = 'http://www.loterias.caixa.gov.br/wps/portal/loterias/landing/megasena/locais-sorte/!ut/p/a1/jc9Rb4IwEAfwj9S_lEJ9LKAFhIzNDJQX0zSNa-LoUsTPPzB7WqLb3dMlv8vdn_TkQPpB3exZXa0b1GWZ--iUyx1fcYkdmNxAsHbbMFpSpHQGxxmkUuRhXAEIeYAiS_IsXtdAEf1vHw9K4K_9jvR3Eq0q5JAoUQQcItw0QVu2FJz-BrJJGcRLlqxB5wb7Ac8y3MGTJ7s5RfzwzSAkb5O_NOpsB1U5reyYqb3zV0M6b0Y3eW3Iq1b6w1TmZhZoyH65qt2gJz86cgxCRsnX5_sBtjjVSS2-AVS_kEU!/dl5/d5/L0lHSklna0tDbEVLQ2xFQSEvb013UUFFTUlBQUNFRWhnQ0tNNHpsR0NrS1ZCQS80SkNoRE13cE1oUWpVbzVDakdweC9aN19IR0s4MThHMEtPTFRDMFFFR0UzS1NKMDBLMi9aNl9IR0s4MThHMEtPTFRDMFFFR0UzS1NKMDBPNy9jb25jdXJzby8yNDUzL21vc3RyYVJlc3VsdGFkby9zaW0!/'

r = requests.get(url)

df = pd.read_html(r.text)

r_text = r.text

df = df[1].copy()

# %%
df
# Out:
#                      Cidade                      Unidade Lotérica  \
# 0                 MACEIO/AL               LOTERIA BRILHO DA SORTE
# 1                 MACAPA/AP          IBC - INTERNET BANKING CAIXA
# 2                 MACAPA/AP          IBC - INTERNET BANKING CAIXA
# 3           PORTO SEGURO/BA                     LOTERICA ELDORADO
# 4   VITORIA DA CONQUISTA/BA                    LOTERICA SAO JORGE
# 5               BRASILIA/DF                     LOTERIA PARKSORTE
# 6               BRASILIA/DF                     PIT STOP LOTERIAS
# 7               BRASILIA/DF                         REAL LOTERIAS
# 8                  SERRA/ES           CASA LOTERICA RAMOS DA ROSA
# 9                FORMOSA/GO                   LOTERICA SONHO REAL
# 10               GOIANIA/GO          IBC - INTERNET BANKING CAIXA
# 11                  CODO/MA                     LOTERIA BOA SORTE
# 12        BELO HORIZONTE/MG                         ZEBRA DE OURO
# ...
