# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = 'https://www.vivareal.com.br/venda/parana/curitiba/apartamento_residencial/?pagina={}'

i = 1 
ret = requests.get(url.format(i))
soup = bs(ret.text)

houses = soup.find_all(
    'a', {'class': 'property-card__content-link js-card-title'})
qtd_imoveis = float(soup.find('strong', {'class': 'results-summary__count'}).text.replace('.',''))

house = houses[0]

df = pd.DataFrame(
    columns=[
        'descricao',
        'endereco',
        'area',
        'quartos',
        'wc',
        'vagas',
        'valor',
        'condominio',
        'wlink'
    ]
)
i = 0

#%%
while qtd_imoveis > df.shape[0]:
    i += 1
    print(f"valor i: {i} \t\t qtd_imoveis: {df.shape[0]}")
    ret = requests.get(url.format(i))
    soup = bs(ret.text)
    houses = soup.find_all(
        'a', {'class': 'property-card__content-link js-card-title'})

    for house in houses:
        try:
            descricao = house.find('span', {'class': 'property-card__title'}).text.strip()
        except:
            descricao = None
        try:
            endereco = house.find('span', {'class': 'property-card__address'}).text.strip()
        except:
            endereco = None
        try:
            area = house.find('span', {'class': 'js-property-card-detail-area'}).text.strip()
        except:
            area = None
        try:
            quartos = house.find('li', {'class': 'property-card__detail-room'}).span.text.strip()
        except:
            quartos = None
        try:
            wc = house.find('li', {'class': 'property-card__detail-bathroom'}).span.text.strip()
        except:
            wc = None
        try:
            vagas = house.find('li', {'class': 'property-card__detail-garage'}).span.text.strip()
        except:
            vagas = None
        try:
            valor = house.find('div', {'class': 'property-card__price'}).p.text.strip()
        except:
            valor = None
        try:
            condominio = house.find('strong', {'class': 'js-condo-price'}).text.strip()
        except:
            condominio = None
        try:
            wlink = 'https://www.vivareal.com.br' + house['href']
        except:
            wlink = None

        df.loc[df.shape[0]] = [
            descricao,
            endereco,
            area,
            quartos,
            wc,
            vagas,
            valor,
            condominio,
            wlink
        ]




#%%

print(descricao)
print(endereco)
print(area)
print(quartos)
print(wc)
print(vagas)
print(valor)
print(condominio)
print(wlink)
#%%


df.to_csv('banco_de_imoveis.csv', sep=';', index=False)



# %%
# Out:
# valor i: 1 		 qtd_imoveis: 0
# valor i: 2 		 qtd_imoveis: 36
# valor i: 3 		 qtd_imoveis: 72
# valor i: 4 		 qtd_imoveis: 108
# valor i: 5 		 qtd_imoveis: 144
# valor i: 6 		 qtd_imoveis: 180
# valor i: 7 		 qtd_imoveis: 216
# valor i: 8 		 qtd_imoveis: 252
# valor i: 9 		 qtd_imoveis: 288
# valor i: 10 		 qtd_imoveis: 324
# valor i: 11 		 qtd_imoveis: 360
# valor i: 12 		 qtd_imoveis: 396
# valor i: 13 		 qtd_imoveis: 432
# valor i: 14 		 qtd_imoveis: 468
# valor i: 15 		 qtd_imoveis: 504
# valor i: 16 		 qtd_imoveis: 540
# valor i: 17 		 qtd_imoveis: 576
# valor i: 18 		 qtd_imoveis: 612
# valor i: 19 		 qtd_imoveis: 648
# valor i: 20 		 qtd_imoveis: 684
# valor i: 21 		 qtd_imoveis: 720
# valor i: 22 		 qtd_imoveis: 756
# valor i: 23 		 qtd_imoveis: 792
# valor i: 24 		 qtd_imoveis: 828
# valor i: 25 		 qtd_imoveis: 864
# valor i: 26 		 qtd_imoveis: 900
# valor i: 27 		 qtd_imoveis: 936
# valor i: 28 		 qtd_imoveis: 972
# valor i: 29 		 qtd_imoveis: 1008
# valor i: 30 		 qtd_imoveis: 1044
# valor i: 31 		 qtd_imoveis: 1080
# valor i: 32 		 qtd_imoveis: 1116
# valor i: 33 		 qtd_imoveis: 1152
# valor i: 34 		 qtd_imoveis: 1188
# valor i: 35 		 qtd_imoveis: 1224
# valor i: 36 		 qtd_imoveis: 1260
# valor i: 37 		 qtd_imoveis: 1296
# valor i: 38 		 qtd_imoveis: 1332
# valor i: 39 		 qtd_imoveis: 1368
# valor i: 40 		 qtd_imoveis: 1404
# valor i: 41 		 qtd_imoveis: 1440
# valor i: 42 		 qtd_imoveis: 1476
# valor i: 43 		 qtd_imoveis: 1512
# valor i: 44 		 qtd_imoveis: 1548
# valor i: 45 		 qtd_imoveis: 1584
# valor i: 46 		 qtd_imoveis: 1620
# valor i: 47 		 qtd_imoveis: 1656
# valor i: 48 		 qtd_imoveis: 1692
# valor i: 49 		 qtd_imoveis: 1728
# valor i: 50 		 qtd_imoveis: 1764
# valor i: 51 		 qtd_imoveis: 1800
# valor i: 52 		 qtd_imoveis: 1836
# valor i: 53 		 qtd_imoveis: 1872
# valor i: 54 		 qtd_imoveis: 1908
# valor i: 55 		 qtd_imoveis: 1944
# valor i: 56 		 qtd_imoveis: 1980
# valor i: 57 		 qtd_imoveis: 2016
# valor i: 58 		 qtd_imoveis: 2052
# valor i: 59 		 qtd_imoveis: 2088
# valor i: 60 		 qtd_imoveis: 2124
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8832/2749319739.py in <module>
#      30     i += 1
#      31     print(f"valor i: {i} \t\t qtd_imoveis: {df.shape[0]}")
# ---> 32     ret = requests.get(url.format(i))
#      33     soup = bs(ret.text)
#      34     houses = soup.find_all(
#
# c:\users\amd\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\users\amd\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\users\amd\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\users\amd\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\users\amd\appdata\local\programs\python\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\users\amd\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\users\amd\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\users\amd\appdata\local\programs\python\python39\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\amd\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# c:\users\amd\appdata\local\programs\python\python39\lib\http\client.py in getresponse(self)
#    1343         try:
#    1344             try:
# -> 1345                 response.begin()
#    1346             except ConnectionError:
#    1347                 self.close()
#
# c:\users\amd\appdata\local\programs\python\python39\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# c:\users\amd\appdata\local\programs\python\python39\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# c:\users\amd\appdata\local\programs\python\python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# c:\users\amd\appdata\local\programs\python\python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\users\amd\appdata\local\programs\python\python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df
# Out:
#                                      descricao  \
# 0     Apartamento com 3 Quartos à Venda, 144m²
# 1                                  Mont Tannat
# 2     Apartamento com 2 Quartos à Venda, 131m²
# 3        Apartamento com  Quarto à Venda, 31m²
# 4     Apartamento com 3 Quartos à Venda, 110m²
# ...                                        ...
# 2119   Apartamento com 3 Quartos à Venda, 93m²
# 2120   Apartamento com 3 Quartos à Venda, 96m²
# 2121  Apartamento com 4 Quartos à Venda, 150m²
# 2122   Apartamento com 3 Quartos à Venda, 92m²
# 2123   Apartamento com 2 Quartos à Venda, 65m²
#
#                                                endereco   area quartos   wc  \
# 0          Rua Rocha Pombo, 904 - Juvevê, Curitiba - PR    144       3    3
# 1     Avenida Visconde de Guarapuava, 3116 - Centro,...  32-72     1-2  1-2
# 2     Rua Comendador Araújo, 279 - Centro, Curitiba ...    131       2    2
# 3       Rua Mariano Torres, 958 - Centro, Curitiba - PR     31       1    1
# 4     Rua Padre Anchieta, 1399 - Champagnat, Curitib...    110       3    3
# ...                                                 ...    ...     ...  ...
# 2119  Rua Jeremias Maciel Perretto, 646 - Campo Comp...     93       3    2
# 2120  Rua Nestor Victor, 750 - Água Verde, Curitiba ...     96       3    3
# 2121      Rua Carneiro Lobo, 614 - Batel, Curitiba - PR    150       4    4
# 2122  Rua Paraguassu, 570 - Alto da Glória, Curitiba...     92       3    3
# 2123  Rua Doutor Alarico Vieira de Alencar, 307 - Ba...     65       2    2
#
#      vagas         valor condominio  \
# 0        2  R$ 1.390.000     R$ 600
# 1      1-3    R$ 239.200       None
# 2        1    R$ 660.000     R$ 800
# 3       --    R$ 136.000     R$ 400
# 4        1    R$ 625.000     R$ 855
# ...    ...           ...        ...
# 2119     2    R$ 599.000     R$ 600
# 2120     1    R$ 550.000     R$ 390
# 2121     2  R$ 1.250.000     R$ 930
# 2122     2    R$ 759.000     R$ 800
# 2123     1    R$ 425.000     R$ 330
#
#                                                   wlink
# 0     https://www.vivareal.com.br/imovel/apartamento...
# 1     https://www.vivareal.com.br/imoveis-lancamento...
# 2     https://www.vivareal.com.br/imovel/apartamento...
# 3     https://www.vivareal.com.br/imovel/apartamento...
# 4     https://www.vivareal.com.br/imovel/apartamento...
# ...                                                 ...
# 2119  https://www.vivareal.com.br/imovel/apartamento...
# 2120  https://www.vivareal.com.br/imovel/apartamento...
# 2121  https://www.vivareal.com.br/imovel/apartamento...
# 2122  https://www.vivareal.com.br/imovel/apartamento...
# 2123  https://www.vivareal.com.br/imovel/apartamento...
#
# [2124 rows x 9 columns]
